# %%
# !git clone https://github.com/vlomme/Decision-Russian-EGE.git

# %%
cd Decision-Russian-EGE/

# %%
# !pip install -r requirements.txt

# %%
# !gdown https://drive.google.com/uc?id=1Z8JFvYs0Am7nBUpM4avE2xOdp3A1wF_2

# %%
# !unzip sat_data.zip

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')

# %%
# !python solution_run.py
# Out:
# Solver 1 is ready!
#
# 12.330470085144043
# Exception during fitting: 'Solver' object has no attribute 'fit'
# Solver 2 is ready!
#
# 28.407050371170044
# Solver 3 is ready!
#
# 40.59800314903259
# Solver 4 is ready!
#
# 42.373035192489624
# Exception during fitting: 'Solver' object has no attribute 'fit'
# Solver 5 is ready!
#
# 42.63620686531067
# Solver 6 is ready!
#
# 42.76696252822876
# Exception during fitting: Expected tensor for argument #1 'indices' to have scalar type Long; but got torch.FloatTensor instead (while checking arguments for embedding)
# Solver 7 is ready!
#
# 46.34046816825867
# Solver 8 is ready!
#
# 49.98783874511719
# Solver 9 is ready!
#
# 51.75547647476196
# Solver 10 is ready!
#
# 52.25906300544739
# Solver 11 is ready!
#
# 52.39287066459656
# Solver 12 is ready!
#
# 52.535768270492554
# Solver 13 is ready!
#
# 58.74166393280029
# Solver 14 is ready!
#
# 62.8540563583374
# Solver 15 is ready!
#
# 84.1632227897644
# h
# ...
